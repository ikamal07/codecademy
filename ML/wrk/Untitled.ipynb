# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./MCC_Radars.csv', sep=';', delimiter=None)

# %%
df.head()
# Out:
#                                    Radar Description            Component  \
# 0  SUPPORT: DRAGON - Push notifications for iClou...   MCC-SRE-Core | All
# 1  SUPPORT: DRAGON - Unable to access Mail - Heal...   MCC-SRE-Core | All
# 2  SUPPORT: DRAGON - Unable to access mail while ...   MCC-SRE-Core | All
# 3  SUPPORT: DRAGON -  Data loss: Unable to recove...   MCC-SRE-Core | All
# 4  SUPPORT: DRAGON -  Unable to enable mail - Ema...   MCC-SRE-Core | All
#
#               Date               Type                       SRE
# 0   Today, 4:42 AM   Analyze (Screen)                 Ravi Kant
# 1   Today, 4:41 AM   Analyze (Screen)     Arun Kumar Kezhucheri
# 2   Today, 4:41 AM   Analyze (Screen)     Arun Kumar Kezhucheri
# 3   Today, 4:33 AM   Analyze (Screen)   Praveen Sriperumbudhuri
# 4   Today, 4:33 AM   Analyze (Screen)   Praveen Sriperumbudhuri

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Radar Description  302 non-null    object
#  1   Component          302 non-null    object
#  2   Date               302 non-null    object
#  3   Type               302 non-null    object
#  4   SRE                302 non-null    object
# dtypes: object(5)
# memory usage: 11.9+ KB

# %%
for col in df.columns:
    print(col)
# Out:
# Radar Description
# Component
# Date
# Type
# SRE

# %%
#df['Date']= pd.to_datetime(df['Date'])

# %%
df1=df[df['Radar Description'].str.contains('SUPPORT')]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 0 to 249
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Radar Description  44 non-null     object
#  1   Component          44 non-null     object
#  2   Date               44 non-null     object
#  3   Type               44 non-null     object
#  4   SRE                44 non-null     object
# dtypes: object(5)
# memory usage: 2.1+ KB

# %%
f = plt.figure()
plt.xticks(rotation=45, ha='right')
f.set_figwidth(10)
f.set_figheight(10)
value_counts = df['SRE'].value_counts()
value_counts[value_counts.values > 0].plot(kind = 'bar')
plt.savefig('alerts.png')

# %%
f = plt.figure()
plt.xticks(rotation=45, ha='right')
f.set_figwidth(10)
f.set_figheight(10)
value_counts = df1['SRE'].value_counts()
value_counts[value_counts.values > 0].plot(kind = 'bar')
plt.savefig('alerts.png')

# %%
ls
# Out:
# MCC1.tsv        MCC_Radars.csv  Untitled.ipynb  alerts.png      ksekar.csv

# %%
df = pd.read_csv('./ksekar.csv', sep=';', delimiter=None)

# %%
df.head()
# Out:
#                                               Ticket           Component  \
# 0                 [DAV] Migrate mosaic alerts to i4c   MCC-SRE-DAV | All
# 1  [MAS] Make changes to Spinnaker template to su...       MAS-SRE | All
# 2  Request for Apple account creation for new ass...       MCC-SRE | All
# 3  Request to delete apple account of Krishna Das...       MCC-SRE | All
# 4   Multiple Alerts for Host st11p09mm-mailprovdr002       MCC-SRE | All
#
#                   Date                                           State  \
# 0    12/12/22, 2:22 PM   P3, Analyze (Screen) - ACS 2306 (12/05-12/16)
# 1    12/12/22, 1:24 PM   P2, Analyze (Screen) - ACS 2306 (12/05-12/16)
# 2   12/12/22, 12:19 PM                                Analyze (Screen)
# 3   12/12/22, 12:19 PM                                          Verify
# 4   12/12/22, 12:01 PM   P3, Analyze (Screen) - ACS 2306 (12/05-12/16)
#
#               SRE
# 0     Sourav Maji
# 1     Gaurav Goel
# 2   Pooja Naregal
# 3   Pooja Naregal
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ticket     578 non-null    object
#  1   Component  577 non-null    object
#  2   Date       577 non-null    object
#  3   State      577 non-null    object
#  4   SRE        577 non-null    object
# dtypes: object(5)
# memory usage: 22.7+ KB

# %%
f = plt.figure()
plt.xticks(rotation=45, ha='right')
f.set_figwidth(10)
f.set_figheight(10)
value_counts = df['SRE'].value_counts()
value_counts[value_counts.values > 0].plot(kind = 'bar')
plt.savefig('alerts.png')

# %%
f = plt.figure()
plt.xticks(rotation=45, ha='right')
f.set_figwidth(10)
f.set_figheight(10)
value_counts = df['Component'].value_counts()
value_counts[value_counts.values > 5].plot(kind = 'bar')
plt.savefig('alerts1.png')

# %%
#Support Radars

# %%
df2=df[df['Ticket'].str.contains('SUPPORT')]
value_counts_sr = df2['SRE'].value_counts()
value_counts_sr[value_counts_sr.values > 0].plot(kind = 'bar')


#value_counts_sr = df['Component' == 'Customer'].value_counts()
#value_counts_sr[value_counts.values>0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2
# Out:
#                                                 Ticket  \
# 21   SUPPORT: DRAGON - Unable to access mail while ...
# 22   SUPPORT: DRAGON - Unable to access Mail - Heal...
# 26   SUPPORT: DRAGON - Push notifications for iClou...
# 27   SUPPORT: DRAGON -  Data loss: Unable to recove...
# 28   SUPPORT: DRAGON -  Unable to enable mail - Ema...
# 29   SUPPORT: DRAGON -  Unable to send mail from @m...
# 68   SUPPORT: DRAGON - Can not search at iCloud.com...
# 69             SUPPORT: DRAGON -  Storage not freed up
# 70                   SUPPORT: DRAGON -  Mail data loss
# 71     SUPPORT: DRAGON - Data loss, request to recover
# 72   SUPPORT: DRAGON - Unable to access webmail, de...
# 102  SUPPORT: ORACLE -  Unable to access mail on iC...
# 104  SUPPORT: ORACLE - Multiple Mail access issues ...
# 105  SUPPORT: DRAGON - Append  Error when trying to...
# 106  SUPPORT: DRAGON - Incorrect Send From name on ...
# 107  SUPPORT: DRAGON - iCloud Mail - Unable to acce...
# ...

# %%
#SUPPORT

# %%
#df1=df[df['description'].str.contains('IMAP:Status:NO')]
df['Date']= pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ticket     578 non-null    object
#  1   Component  577 non-null    object
#  2   Date       577 non-null    datetime64[ns]
#  3   State      577 non-null    object
#  4   SRE        577 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 22.7+ KB

# %%
df.resample('MS').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [107], in <cell line: 1>()
# ----> 1 df.resample('MS').sum()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:10541, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10525 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   10526 def resample(
#   10527     self,
#    (...)
#   10539     offset: TimedeltaConvertibleTypes | None = None,
#   10540 ) -> Resampler:
# > 10541     return super().resample(
#   10542         rule=rule,
#   10543         axis=axis,
#   10544         closed=closed,
#   10545         label=label,
#   10546         convention=convention,
#   10547         kind=kind,
#   10548         loffset=loffset,
#   10549         base=base,
#   10550         on=on,
#   10551         level=level,
# ...
