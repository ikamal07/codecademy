# %%
pwd
# Out:
# '/Users/kamallakannansekar/Documents/codecdemy/ML'

# %%
cd ..
# Out:
# /Users/kamallakannansekar/Documents/codecdemy

# %%
pwd
# Out:
# '/Users/kamallakannansekar/Documents/codecdemy'

# %%
ls
# Out:
# Algorithms and Data Structures.ipynb  Untitled Folder 1/
# Andrew.rtf                            WorldCupMatches.csv
# Capstone1/                            dataset1.csv
# Chaithra.rtf                          dataset2.csv
# DISN/                                 dataset3.csv
# DJI.csv                               dataset4.csv
# ML/                                   goals.csv
# NFLX.csv                              lime.png
# NFLX_daily_by_quarter.csv             limesale.ipynb
# Rough Notes.ipynb                     my_bar_chart.png
# Rought_Practice.ipynb                 my_line_graph.png
# Temp/                                 my_side_by_side.png
# Tick/                                 my_stacked_bar.png
# Untitled 13.rtf                       netflix_visualizations.ipynb
# Untitled 178.rtf                      sales_times.csv
# Untitled 20.rtf                       sample1.csv
# Untitled 208.rtf                      survey.csv

# %%
ls /Users/kamallakannansekar/Downloads/incidents-3.csv
# Out:
# /Users/kamallakannansekar/Downloads/incidents-3.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/kamallakannansekar/Downloads/incidents-3.csv')
df['Count']= 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3419 entries, 0 to 3418
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          3419 non-null   object
#  1   incident_number             3419 non-null   int64
#  2   description                 3419 non-null   object
#  3   service_id                  3419 non-null   object
#  4   service_name                3419 non-null   object
#  5   escalation_policy_id        3419 non-null   object
#  6   escalation_policy_name      3419 non-null   object
#  7   created_on                  3419 non-null   object
#  8   resolved_on                 3419 non-null   object
#  9   seconds_to_first_ack        2777 non-null   float64
#  10  seconds_to_resolve          3338 non-null   float64
#  11  auto_resolved               3419 non-null   int64
#  12  escalation_count            3419 non-null   int64
# ...

# %%
df['created_on']= pd.to_datetime(df['created_on'])

# %%
df['created_on']
# Out:
# 0       2021-10-14 07:02:08-07:00
# 1       2021-10-14 07:11:08-07:00
# 2       2021-10-14 07:11:08-07:00
# 3       2021-10-14 08:10:09-07:00
# 4       2021-10-14 11:31:07-07:00
#                   ...
# 3414    2022-10-13 11:43:05-07:00
# 3415    2022-10-13 11:53:04-07:00
# 3416    2022-10-13 12:11:05-07:00
# 3417    2022-10-13 12:44:08-07:00
# 3418    2022-10-13 17:38:06-07:00
# Name: created_on, Length: 3419, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3419 entries, 0 to 3418
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          3419 non-null   object
#  1   incident_number             3419 non-null   int64
#  2   description                 3419 non-null   object
#  3   service_id                  3419 non-null   object
#  4   service_name                3419 non-null   object
#  5   escalation_policy_id        3419 non-null   object
#  6   escalation_policy_name      3419 non-null   object
#  7   created_on                  3419 non-null   object
#  8   resolved_on                 3419 non-null   object
#  9   seconds_to_first_ack        2777 non-null   float64
#  10  seconds_to_resolve          3338 non-null   float64
#  11  auto_resolved               3419 non-null   int64
#  12  escalation_count            3419 non-null   int64
# ...

# %%
df['created_on'] = pd.to_datetime(df['created_on'], utc=True).dt.date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3419 entries, 0 to 3418
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          3419 non-null   object
#  1   incident_number             3419 non-null   int64
#  2   description                 3419 non-null   object
#  3   service_id                  3419 non-null   object
#  4   service_name                3419 non-null   object
#  5   escalation_policy_id        3419 non-null   object
#  6   escalation_policy_name      3419 non-null   object
#  7   created_on                  3419 non-null   object
#  8   resolved_on                 3419 non-null   object
#  9   seconds_to_first_ack        2777 non-null   float64
#  10  seconds_to_resolve          3338 non-null   float64
#  11  auto_resolved               3419 non-null   int64
#  12  escalation_count            3419 non-null   int64
# ...

# %%
df.head(10)
# Out:
#                id  incident_number  \
# 0  Q1J8ZRXYUPFQ2G          3019055
# 1  Q0AE1ZB1JNTUVK          3019059
# 2  Q3ZTLSQKTZHGK6          3019060
# 3  Q25CRUZUW3TTXK          3019112
# 4  Q1SEYSY9IHX4AY          3019257
# 5  Q1DYPC3TVCX5N0          3019889
# 6  Q2PYQ53RJWW7IP          3019933
# 7  Q3U1NA8M4WT66H          3019934
# 8  Q2LM61OGT1RKHP          3019938
# 9  Q1FK17ZXIS0VEO          3019966
#
#                                          description service_id  \
# 0     CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
# 1  CRITICAL : Mail2 Web Client (WWW) - Error Catc...    P5ZIEZ2
# 2  CRITICAL : Mail2 Web Client (WWW) - Startup Fa...    P5ZIEZ2
# 3     CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
# 4  CRITICAL : Mail2 Web Client (WWW) - Error Catc...    P5ZIEZ2
# 5  CRITICAL : [xrail] carddav -> unhealthy upstreams    P5ZIEZ2
# 6             CRITICAL : carddav - Rejected Requests    P5ZIEZ2
# ...

# %%
from matplotlib import pyplot as plt

# %%
f = plt.figure()
plt.xticks(rotation=45, ha='right')
f.set_figwidth(10)
f.set_figheight(10)
value_counts = df['description'].value_counts()
value_counts[value_counts.values > 25].plot(kind = 'bar')
plt.savefig('alerts.png')

# %%
df['description'].tail()
# Out:
# 3414    CRITICAL : identity service: account service e...
# 3415    CRITICAL : identity service: account service e...
# 3416    High 5XX response code from Xrail to commandce...
# 3417    CRITICAL : calendarsupport - Too many log4j er...
# 3418           Mail pod restart Alert | 1 alert is firing
# Name: description, dtype: object

# %%
#pwd
#df.groupby('Company Name')['Amount'].agg(['sum','count'])
#df.groupby('Company Name').agg({'Amount': ['sum','count']})

# %%
#df2=df.groupby('description'),['created_on'].agg(['sum','count'])
#df.groupby('description').agg({'created_on': ['count','sum']})

# %%
df1=df[df['description'].str.contains('IMAP:Status:NO')]

# %%
df1.head()
# Out:
#                 id  incident_number  \
# 0   Q1J8ZRXYUPFQ2G          3019055
# 3   Q25CRUZUW3TTXK          3019112
# 10  Q3BO3NVZE709Y1          3020067
# 34  Q1HXDACW7N73E4          3023163
# 65  Q0WQLQMXRE4EJS          3026426
#
#                                        description service_id  \
# 0   CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
# 3   CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
# 10  CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
# 34  CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
# 65  CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
#
#               service_name escalation_policy_id        escalation_policy_name  \
# 0   iCloud Mail SRE Oncall              PZPCULB  FTS - iCloud Mail SRE Oncall
# 3   iCloud Mail SRE Oncall              PZPCULB  FTS - iCloud Mail SRE Oncall
# 10  iCloud Mail SRE Oncall              PZPCULB  FTS - iCloud Mail SRE Oncall
# ...

# %%
#df.Date = pd.to_datetime(df.Date)
#df.set_index('Date', inplace=True)
#df.resample('MS').sum()
#df.resample('QS').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 df.Date = pd.to_datetime(df.Date)
#       2 df.set_index('Date', inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
df1.created_on = pd.to_datetime(df.created_on, utc=True)
# Out:
# /var/folders/v_/dt4zl16x3zbd4h2zk9d9rbs00000gn/T/ipykernel_3289/516203584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.created_on = pd.to_datetime(df.created_on, utc=True)

# %%
df1.set_index('created_on', inplace=True)

# %%
df_monthly = df1.resample('MS').sum()
#df1.resample('QS').sum()

# %%
df_quarterly = df1.resample('QS').sum()

# %%
df_monthly
# Out:
#                            incident_number  seconds_to_first_ack  \
# created_on
# 2021-10-01 00:00:00+00:00         18134290                 213.0
# 2021-11-01 00:00:00+00:00        113082721                1428.0
# 2021-12-01 00:00:00+00:00         40018430                1542.0
# 2022-01-01 00:00:00+00:00         43449412                 353.0
# 2022-02-01 00:00:00+00:00         24986337                 146.0
# 2022-03-01 00:00:00+00:00         44303645                 830.0
# 2022-04-01 00:00:00+00:00         86046709                 982.0
# 2022-05-01 00:00:00+00:00         70769185                 807.0
# 2022-06-01 00:00:00+00:00         68095282                 501.0
# 2022-07-01 00:00:00+00:00         16328488                 115.0
# 2022-08-01 00:00:00+00:00         16445315                 213.0
# 2022-09-01 00:00:00+00:00                0                   0.0
# 2022-10-01 00:00:00+00:00          3342694                 314.0
#
# ...

# %%
y = df_monthly[['Count']].values
X = np.array(['Oct_21','Nov_21', 'Dec_21', 'Jan_22', 'Feb_22', 'Mar_22', 'Apr_22', 'May_22', 'Jun_22', 'Jul_22', 'Aug_22', 'Sep_22', 'Oct_22'])
#y = df_monthly[['created_on']]
#plt.plot(X, y)

# %%
f = plt.figure()
plt.title("IMAP NO Montly Distribution")
plt.xticks(rotation=45, ha='right')
plt.ylabel("Count of Alerts")
plt.xlabel("Month")
f.set_figwidth(10)
f.set_figheight(10)
plt.plot(X, y)

# %% [raw]
# df1=df[df['description'].str.contains('IMAP:Status:NO')]
# df1.created_on = pd.to_datetime(df.created_on)
# df1.set_index('created_on', inplace=True)
# df_monthly = df1.resample('MS').sum()
# y = df_monthly[['Count']].values
# X = np.array(['Oct_21','Nov_21', 'Dec_21', 'Jan_22', 'Feb_22', 'Mar_22', 'Apr_22', 'May_22', 'Jun_22', 'Jul_22', 'Aug_22', 'Sep_22', 'Oct_22'])
# f = plt.figure()
# plt.title("IMAP NO Montly Distribution")
# plt.xticks(rotation=45, ha='right')
# plt.ylabel("Count of Alerts")
# plt.xlabel("Month")
# f.set_figwidth(10)
# f.set_figheight(10)
# plt.plot(X, y)

# %%
df.head()
# Out:
#                id  incident_number  \
# 0  Q1J8ZRXYUPFQ2G          3019055
# 1  Q0AE1ZB1JNTUVK          3019059
# 2  Q3ZTLSQKTZHGK6          3019060
# 3  Q25CRUZUW3TTXK          3019112
# 4  Q1SEYSY9IHX4AY          3019257
#
#                                          description service_id  \
# 0     CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
# 1  CRITICAL : Mail2 Web Client (WWW) - Error Catc...    P5ZIEZ2
# 2  CRITICAL : Mail2 Web Client (WWW) - Startup Fa...    P5ZIEZ2
# 3     CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
# 4  CRITICAL : Mail2 Web Client (WWW) - Error Catc...    P5ZIEZ2
#
#              service_name escalation_policy_id        escalation_policy_name  \
# 0  iCloud Mail SRE Oncall              PZPCULB  FTS - iCloud Mail SRE Oncall
# 1  iCloud Mail SRE Oncall              PZPCULB  FTS - iCloud Mail SRE Oncall
# 2  iCloud Mail SRE Oncall              PZPCULB  FTS - iCloud Mail SRE Oncall
# ...

# %%
df2=df[df['description'].str.contains('carddav - Too many errors')]
df2.info()
df2.created_on = pd.to_datetime(df.created_on, utc=True)
df2.set_index('created_on', inplace=True)
df_monthly = df2.resample('MS').sum()
#df['created_on'] = pd.to_datetime(df['created_on'], utc=True).dt.date
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172 entries, 9 to 1991
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          172 non-null    object
#  1   incident_number             172 non-null    int64
#  2   description                 172 non-null    object
#  3   service_id                  172 non-null    object
#  4   service_name                172 non-null    object
#  5   escalation_policy_id        172 non-null    object
#  6   escalation_policy_name      172 non-null    object
#  7   created_on                  172 non-null    object
#  8   resolved_on                 172 non-null    object
#  9   seconds_to_first_ack        124 non-null    float64
#  10  seconds_to_resolve          171 non-null    float64
#  11  auto_resolved               172 non-null    int64
#  12  escalation_count            172 non-null    int64
# ...

# %%
df_monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8 entries, 2021-10-01 00:00:00+00:00 to 2022-05-01 00:00:00+00:00
# Freq: MS
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   incident_number        8 non-null      int64
#  1   seconds_to_first_ack   8 non-null      float64
#  2   seconds_to_resolve     8 non-null      float64
#  3   auto_resolved          8 non-null      int64
#  4   escalation_count       8 non-null      int64
#  5   auto_escalation_count  8 non-null      int64
#  6   acknowledge_count      8 non-null      int64
#  7   assignment_count       8 non-null      int64
#  8   Count                  8 non-null      int64
# dtypes: float64(2), int64(7)
# memory usage: 640.0 bytes

# %%
df_monthly
# Out:
#                            incident_number  seconds_to_first_ack  \
# created_on
# 2021-10-01 00:00:00+00:00        109088145                1075.0
# 2021-11-01 00:00:00+00:00        122158850                1090.0
# 2021-12-01 00:00:00+00:00         52286643                 822.0
# 2022-01-01 00:00:00+00:00        102418205                 527.0
# 2022-02-01 00:00:00+00:00         34443240                 247.0
# 2022-03-01 00:00:00+00:00         41061132                 350.0
# 2022-04-01 00:00:00+00:00         31882570                 161.0
# 2022-05-01 00:00:00+00:00         38557336                 336.0
#
#                            seconds_to_resolve  auto_resolved  \
# created_on
# 2021-10-01 00:00:00+00:00            108345.0              0
# 2021-11-01 00:00:00+00:00            104088.0              2
# 2021-12-01 00:00:00+00:00             41221.0              0
# 2022-01-01 00:00:00+00:00             67615.0              0
# ...

# %%
y = df_monthly[['Count']].values
len(y)
#y = df_monthly[['Count']].values.fillna(0)
#X = np.array(['Oct_21','Nov_21', 'Dec_21', 'Jan_22', 'Feb_22', 'Mar_22', 'Apr_22', 'May_22', 'Jun_22', 'Jul_22', 'Aug_22', 'Sep_22', 'Oct_22'])
#f = plt.figure()
#plt.title("carddav - Too many errors")
#plt.xticks(rotation=45, ha='right')
#plt.ylabel("Count of Alerts")
#plt.xlabel("Month")
#f.set_figwidth(10)
#f.set_figheight(10)
#plt.plot(X, y)
# Out:
# 8

# %%
X
# Out:
# array(['Oct_21', 'Nov_21', 'Dec_21', 'Jan_22', 'Feb_22', 'Mar_22',
#        'Apr_22', 'May_22', 'Jun_22', 'Jul_22', 'Aug_22', 'Sep_22',
#        'Oct_22'], dtype='<U6')

# %%
y = np.append(y, [0])
y = np.append(y, [0])
y = np.append(y, [0])
y = np.append(y, [0])
y = np.append(y, [0])

# %%
y
# Out:
# array([36, 40, 17, 33, 11, 13, 10, 12,  0,  0,  0,  0,  0])

# %%
f = plt.figure()
plt.title("carddav - Too many errors")
plt.xticks(rotation=45, ha='right')
plt.ylabel("Count of Alerts")
plt.xlabel("Month")
f.set_figwidth(10)
f.set_figheight(10)
plt.plot(X, y)

# %%
df3=df[df['description'].str.contains('caldavj - High Error Rate')]
df3.info()
df3.created_on = pd.to_datetime(df.created_on, utc=True)
df3.set_index('created_on', inplace=True)
df_monthly = df3.resample('MS').sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 40 to 2022
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          105 non-null    object
#  1   incident_number             105 non-null    int64
#  2   description                 105 non-null    object
#  3   service_id                  105 non-null    object
#  4   service_name                105 non-null    object
#  5   escalation_policy_id        105 non-null    object
#  6   escalation_policy_name      105 non-null    object
#  7   created_on                  105 non-null    object
#  8   resolved_on                 105 non-null    object
#  9   seconds_to_first_ack        79 non-null     float64
#  10  seconds_to_resolve          104 non-null    float64
#  11  auto_resolved               105 non-null    int64
#  12  escalation_count            105 non-null    int64
# ...

# %%
df_monthly
# Out:
#                            incident_number  seconds_to_first_ack  \
# created_on
# 2021-10-01 00:00:00+00:00         45436263                 373.0
# 2021-11-01 00:00:00+00:00         57922944                 647.0
# 2021-12-01 00:00:00+00:00         55227813                 791.0
# 2022-01-01 00:00:00+00:00         43448406                 175.0
# 2022-02-01 00:00:00+00:00         25011153                 101.0
# 2022-03-01 00:00:00+00:00         25284942                1053.0
# 2022-04-01 00:00:00+00:00         54174976                 648.0
# 2022-05-01 00:00:00+00:00         19277206                 791.0
#
#                            seconds_to_resolve  auto_resolved  \
# created_on
# 2021-10-01 00:00:00+00:00             18960.0              0
# 2021-11-01 00:00:00+00:00             63318.0              2
# 2021-12-01 00:00:00+00:00             70924.0              1
# 2022-01-01 00:00:00+00:00             35376.0              0
# ...

# %%
y = df_monthly[['Count']].values
len(y)
# Out:
# 8

# %%
y = np.append(y, [0])
y = np.append(y, [0])
y = np.append(y, [0])
y = np.append(y, [0])
y = np.append(y, [0])

# %%
y
f = plt.figure()
plt.title("caldavj - High Error Rate")
plt.xticks(rotation=45, ha='right')
plt.ylabel("Count of Alerts")
plt.xlabel("Month")
f.set_figwidth(10)
f.set_figheight(10)
plt.plot(X, y)

# %%
#Caldavj - GC Time too high

# %%
df4=df[df['description'].str.contains('Caldavj - GC Time too high')]
df4.info()
df4.created_on = pd.to_datetime(df.created_on, utc=True)
df4.set_index('created_on', inplace=True)
df_monthly = df4.resample('MS').sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 446 to 3150
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          99 non-null     object
#  1   incident_number             99 non-null     int64
#  2   description                 99 non-null     object
#  3   service_id                  99 non-null     object
#  4   service_name                99 non-null     object
#  5   escalation_policy_id        99 non-null     object
#  6   escalation_policy_name      99 non-null     object
#  7   created_on                  99 non-null     object
#  8   resolved_on                 99 non-null     object
#  9   seconds_to_first_ack        78 non-null     float64
#  10  seconds_to_resolve          99 non-null     float64
#  11  auto_resolved               99 non-null     int64
#  12  escalation_count            99 non-null     int64
# ...

# %%
df_monthly
# Out:
#                            incident_number  seconds_to_first_ack  \
# created_on
# 2021-11-01 00:00:00+00:00          6120071                  19.0
# 2021-12-01 00:00:00+00:00          3072230                  15.0
# 2022-01-01 00:00:00+00:00          6221772                  47.0
# 2022-02-01 00:00:00+00:00          3117339                  16.0
# 2022-03-01 00:00:00+00:00         50577029                1774.0
# 2022-04-01 00:00:00+00:00        121138983                1414.0
# 2022-05-01 00:00:00+00:00         38652465                1085.0
# 2022-06-01 00:00:00+00:00                0                   0.0
# 2022-07-01 00:00:00+00:00         71967792                1890.0
# 2022-08-01 00:00:00+00:00          9853559                  75.0
# 2022-09-01 00:00:00+00:00          6637165                 140.0
#
#                            seconds_to_resolve  auto_resolved  \
# created_on
# 2021-11-01 00:00:00+00:00               644.0              0
# ...

# %%
y = df_monthly[['Count']].values
len(y)
y
# Out:
# array([[ 2],
#        [ 1],
#        [ 2],
#        [ 1],
#        [16],
#        [38],
#        [12],
#        [ 0],
#        [22],
#        [ 3],
#        [ 2]])

# %%
y = np.insert(y, 0, 0, axis=0)
y = np.append(y, [0])
y
# Out:
# array([ 0,  2,  1,  2,  1, 16, 38, 12,  0, 22,  3,  2,  0])

# %%
f = plt.figure()
plt.title("Caldavj - GC Time too high")
plt.xticks(rotation=45, ha='right')
plt.ylabel("Count of Alerts")
plt.xlabel("Month")
f.set_figwidth(10)
f.set_figheight(10)
plt.plot(X, y)

# %%
y
# Out:
# array([ 0,  2,  1,  2,  1, 16, 38, 12,  0, 22,  3,  2,  0])

# %%
df5=df[df['description'].str.contains('xrail')]
df5.info()
df5.created_on = pd.to_datetime(df.created_on, utc=True)
df5.set_index('created_on', inplace=True)
df_monthly = df5.resample('MS').sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 344 entries, 5 to 3375
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          344 non-null    object
#  1   incident_number             344 non-null    int64
#  2   description                 344 non-null    object
#  3   service_id                  344 non-null    object
#  4   service_name                344 non-null    object
#  5   escalation_policy_id        344 non-null    object
#  6   escalation_policy_name      344 non-null    object
#  7   created_on                  344 non-null    object
#  8   resolved_on                 344 non-null    object
#  9   seconds_to_first_ack        303 non-null    float64
#  10  seconds_to_resolve          330 non-null    float64
#  11  auto_resolved               344 non-null    int64
#  12  escalation_count            344 non-null    int64
# ...

# %%
y = df_monthly[['Count']].values
len(y)
y
# Out:
# array([[36],
#        [23],
#        [31],
#        [18],
#        [ 1],
#        [38],
#        [25],
#        [29],
#        [25],
#        [50],
#        [21],
#        [24],
#        [23]])

# %%
f = plt.figure()
plt.title("All Pages related of xrail")
plt.xticks(rotation=45, ha='right')
plt.ylabel("Count of Alerts")
plt.xlabel("Month")
f.set_figwidth(10)
f.set_figheight(10)
plt.plot(X, y)

# %%
df = pd.read_csv('/Users/kamallakannansekar/Downloads/incidents-3.csv')
df['Count']= 1

# %%
df.head()
# Out:
#                id  incident_number  \
# 0  Q1J8ZRXYUPFQ2G          3019055
# 1  Q0AE1ZB1JNTUVK          3019059
# 2  Q3ZTLSQKTZHGK6          3019060
# 3  Q25CRUZUW3TTXK          3019112
# 4  Q1SEYSY9IHX4AY          3019257
#
#                                          description service_id  \
# 0     CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
# 1  CRITICAL : Mail2 Web Client (WWW) - Error Catc...    P5ZIEZ2
# 2  CRITICAL : Mail2 Web Client (WWW) - Startup Fa...    P5ZIEZ2
# 3     CRITICAL : PROD: MGW: IMAP:Status:NO (20 mins)    P5ZIEZ2
# 4  CRITICAL : Mail2 Web Client (WWW) - Error Catc...    P5ZIEZ2
#
#              service_name escalation_policy_id        escalation_policy_name  \
# 0  iCloud Mail SRE Oncall              PZPCULB  FTS - iCloud Mail SRE Oncall
# 1  iCloud Mail SRE Oncall              PZPCULB  FTS - iCloud Mail SRE Oncall
# 2  iCloud Mail SRE Oncall              PZPCULB  FTS - iCloud Mail SRE Oncall
# ...

# %%
df5=df[df['escalation_policy_name'].str.contains('FTS - iCloud Mail SRE Oncall')]
df5.info()
df5.created_on = pd.to_datetime(df.created_on, utc=True)
df5.set_index('created_on', inplace=True)
df_monthly = df5.resample('MS').sum()
#FTS - iCloud Mail SRE Oncall
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3419 entries, 0 to 3418
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          3419 non-null   object
#  1   incident_number             3419 non-null   int64
#  2   description                 3419 non-null   object
#  3   service_id                  3419 non-null   object
#  4   service_name                3419 non-null   object
#  5   escalation_policy_id        3419 non-null   object
#  6   escalation_policy_name      3419 non-null   object
#  7   created_on                  3419 non-null   object
#  8   resolved_on                 3419 non-null   object
#  9   seconds_to_first_ack        2777 non-null   float64
#  10  seconds_to_resolve          3338 non-null   float64
#  11  auto_resolved               3419 non-null   int64
#  12  escalation_count            3419 non-null   int64
# ...

# %%
df_monthly
# Out:
#                            incident_number  seconds_to_first_ack  \
# created_on
# 2021-10-01 00:00:00+00:00        584474185                8617.0
# 2021-11-01 00:00:00+00:00       1176013112               12546.0
# 2021-12-01 00:00:00+00:00        861033313               18701.0
# 2022-01-01 00:00:00+00:00        815956034                8437.0
# 2022-02-01 00:00:00+00:00        441325746                4675.0
# 2022-03-01 00:00:00+00:00        821257340               17436.0
# 2022-04-01 00:00:00+00:00       1051694568               12192.0
# 2022-05-01 00:00:00+00:00        898022921               13825.0
# 2022-06-01 00:00:00+00:00        859545637               15070.0
# 2022-07-01 00:00:00+00:00        836335221                9965.0
# 2022-08-01 00:00:00+00:00        677986061                9718.0
# 2022-09-01 00:00:00+00:00       1343437598               25680.0
# 2022-10-01 00:00:00+00:00        524494449                4434.0
#
# ...

# %%
y = df_monthly[['Count']].values
f = plt.figure()
plt.title("Total Pages Over Months")
plt.xticks(rotation=45, ha='right')
plt.ylabel("Count of Alerts")
plt.xlabel("Month")
f.set_figwidth(10)
f.set_figheight(10)
plt.plot(X, y)
