# %%
ls
# Out:
# New_Screen_3_7_2022.csv  Tickertape.ipynb

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

df = pd.read_csv("New_Screen_3_7_2022.csv")

# %%
#df.head()
print(df.describe())
# Out:
#          Market Cap   Close Price     PE Ratio  % Away From 52W High  \
# count  1.000000e+02    100.000000   100.000000            100.000000
# mean   1.710446e+05   2699.201000    73.099247             37.598504
# std    2.259192e+05   5238.550186   185.333082             24.613272
# min    4.347807e+04     74.550000   -12.859102              0.228592
# 25%    5.804584e+04    508.500000    16.259840             18.500385
# 50%    8.740892e+04   1083.375000    32.133776             32.142240
# 75%    1.845606e+05   2680.625000    68.224558             49.313532
# max    1.630441e+06  41375.800000  1632.472280            120.866713
#
#              ROCE  Debt to Equity  5Y Historical Revenue Growth   Sector PE  \
# count   99.000000       92.000000                     97.000000  100.000000
# mean    23.121461      375.007059                     13.336422   28.457678
# std     28.768838     2803.847273                     10.822373   49.829164
# ...

# %%
set_xl = df['% Away From 52W High']

# %%
sns.violinplot(data=set_xl)
# Out:
# <AxesSubplot:>

# %%
roce_y = df['ROCE']
plt.figure(figsize=(10,8))
sns.violinplot(data=roce_y)
# Out:
# <AxesSubplot:>

# %%
debt_equity = df['Debt to Equity']

# %%
plt.figure(figsize=(14,12))
sns.violinplot(data=debt_equity)
# Out:
# <AxesSubplot:>

# %%
Earnings_Quality_Rank = df['Earnings Quality Rank']

# %%
plt.figure(figsize=(14,12))
sns.violinplot(data=Earnings_Quality_Rank)
# Out:
# <AxesSubplot:>

# %%
Percentage_Upside = df['Percentage Upside']
plt.figure(figsize=(14,12))
sns.violinplot(data=Percentage_Upside)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
#!pip install yfinance
import yfinance as yf
#%matplotlib inline

start = "2014-01-01"
end = '2019-1-01'
tcs = yf.download('TCS',start,end)
infy = yf.download('INFY',start,end)
wipro = yf.download('WIPRO.NS',start,end)

tcs['Open'].plot(label = 'TCS', figsize = (15,7))
infy['Open'].plot(label = "Infosys")
wipro['Open'].plot(label = 'Wipro')
plt.title('Stock Prices of TCS, Infosys and Wipro')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [14], in <cell line: 7>()
#       5 from pandas.plotting import scatter_matrix
#       6 #!pip install yfinance
# ----> 7 import yfinance as yf
#       8 #%matplotlib inline
#      10 start = "2014-01-01"
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
#!pip install yfinance
import yfinance as yf
#%matplotlib inline

start = "2014-01-01"
end = '2019-01-01'
tcs = yf.download('TCS.NS',start,end)
infy = yf.download('INFY.NS',start,end)
wipro = yf.download('WIPRO.NS',start,end)
AAPL = yf.download('AAPL',start,end)

tcs['Open'].plot(label = 'TCS', figsize = (15,7))
infy['Open'].plot(label = "Infosys")
wipro['Open'].plot(label = 'Wipro')
AAPL['Open'].plot(label = 'AAPL')
plt.legend()
plt.title('Stock Prices of TCS, Infosys,AAPL and Wipro')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Text(0.5, 1.0, 'Stock Prices of TCS, Infosys,AAPL and Wipro')

# %%
df = pd.read_csv("New_Screen_3_7_2022.csv")

# %%
correlation = df.corr()
print(correlation)
# Out:
#                                Market Cap  Close Price  PE Ratio  \
# Market Cap                       1.000000    -0.051524 -0.000709
# Close Price                     -0.051524     1.000000  0.008217
# PE Ratio                        -0.000709     0.008217  1.000000
# % Away From 52W High            -0.186188    -0.099071  0.095185
# ROCE                            -0.084702     0.271538 -0.039657
# Debt to Equity                  -0.043164    -0.029425 -0.037525
# 5Y Historical Revenue Growth     0.023964     0.021493  0.297387
# Sector PE                       -0.048142     0.221009  0.042645
# No. of analysts with buy reco    0.227807    -0.185557 -0.246250
# Percentage Buy Reco’s            0.025442    -0.173830 -0.163059
# Percentage Upside               -0.017739    -0.121823 -0.187213
# Fundamental Score                0.164931     0.191122 -0.030168
# Value Momentum Rank              0.012895    -0.161231 -0.205566
# ...

# %%
df = pd.read_csv("sim_ticker.csv")

# %%
correlation = df.corr()
print(correlation)
# Out:
#                                Market Cap  PE Ratio  Return on Equity  \
# Market Cap                       1.000000 -0.001750          0.038959
# PE Ratio                        -0.001750  1.000000         -0.000157
# Return on Equity                 0.038959 -0.000157          1.000000
# Return on Investment             0.064642 -0.000124          0.308782
# % Away From 52W High            -0.085936 -0.008917         -0.007661
# 6M Return                       -0.035656  0.005675         -0.002119
# Debt to Equity                  -0.016484  0.000115         -0.146848
# Earning Power                    0.001538  0.000013         -0.016297
# Long Term Debt to Equity        -0.011135  0.000015         -0.099599
# 5Y Historical Revenue Growth     0.049091 -0.021196          0.064283
# 1Y Forward Revenue Growth        0.006105 -0.018919         -0.060069
# Sector PE                        0.001650  0.000853         -0.010706
# ...

# %%
Percentage_Upside = df['ROCE']
plt.figure(figsize=(14,12))
sns.violinplot(data=Percentage_Upside)
# Out:
# <AxesSubplot:>
